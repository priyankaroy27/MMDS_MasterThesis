# %%
# !pip install pip==23.2

# %%
# !pip install pytorch-lightning==1.6.5

# %%
# !pip install pyannote.database==5.0.1 pyannote.audio==3.0.0

# %%
# !pip install -qq rich

# %%
# %cd /content/
# !git clone https://github.com/pyannote/AMI-diarization-setup
# %cd /content/AMI-diarization-setup/pyannote/
# !bash download_ami_sdm_mini.sh

# %%
# !pip install "typer[all]"

# %%
# !PYANNOTE_DATABASE_CONFIG="/work/proy/AMI-diarization-setup/pyannote/database.yml" pyannote-database info AMI-SDM.SpeakerDiarization.mini
# Out:
# 'AMI-SDM.SpeakerDiarization.only_words' found in /work/proy/AMI-diarization-setup/pyannote/database.yml does not define the 'scope' of speaker labels (file, database, or global). Setting it to 'file'.
# 'AMI-SDM.SpeakerDiarization.mini' found in /work/proy/AMI-diarization-setup/pyannote/database.yml does not define the 'scope' of speaker labels (file, database, or global). Setting it to 'file'.
# 'AMI.SpeakerDiarization.only_words' found in /work/proy/AMI-diarization-setup/pyannote/database.yml does not define the 'scope' of speaker labels (file, database, or global). Setting it to 'file'.
# 'AMI.SpeakerDiarization.mini' found in /work/proy/AMI-diarization-setup/pyannote/database.yml does not define the 'scope' of speaker labels (file, database, or global). Setting it to 'file'.
# 'AMI.SpeakerDiarization.word_and_vocalsounds' found in /work/proy/AMI-diarization-setup/pyannote/database.yml does not define the 'scope' of speaker labels (file, database, or global). Setting it to 'file'.
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:284: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(file_uem, names=names, dtype=dtype, delim_whitespace=True)
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:178: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:284: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(file_uem, names=names, dtype=dtype, delim_whitespace=True)
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:178: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:284: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(file_uem, names=names, dtype=dtype, delim_whitespace=True)
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:178: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:284: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(file_uem, names=names, dtype=dtype, delim_whitespace=True)
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:178: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:284: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(file_uem, names=names, dtype=dtype, delim_whitespace=True)
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:178: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:284: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(file_uem, names=names, dtype=dtype, delim_whitespace=True)
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:178: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:284: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(file_uem, names=names, dtype=dtype, delim_whitespace=True)
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:178: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:284: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(file_uem, names=names, dtype=dtype, delim_whitespace=True)
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:178: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:284: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(file_uem, names=names, dtype=dtype, delim_whitespace=True)
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:178: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:284: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(file_uem, names=names, dtype=dtype, delim_whitespace=True)
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:178: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:284: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(file_uem, names=names, dtype=dtype, delim_whitespace=True)
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:178: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:284: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(file_uem, names=names, dtype=dtype, delim_whitespace=True)
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:178: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:284: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(file_uem, names=names, dtype=dtype, delim_whitespace=True)
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:178: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:284: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(file_uem, names=names, dtype=dtype, delim_whitespace=True)
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:178: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:284: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(file_uem, names=names, dtype=dtype, delim_whitespace=True)
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:178: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:284: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(file_uem, names=names, dtype=dtype, delim_whitespace=True)
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:178: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:284: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(file_uem, names=names, dtype=dtype, delim_whitespace=True)
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:178: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:284: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(file_uem, names=names, dtype=dtype, delim_whitespace=True)
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:178: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:284: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(file_uem, names=names, dtype=dtype, delim_whitespace=True)
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:178: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:284: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(file_uem, names=names, dtype=dtype, delim_whitespace=True)
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:178: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:284: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(file_uem, names=names, dtype=dtype, delim_whitespace=True)
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:178: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:284: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(file_uem, names=names, dtype=dtype, delim_whitespace=True)
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:178: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:284: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(file_uem, names=names, dtype=dtype, delim_whitespace=True)
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:178: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:284: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(file_uem, names=names, dtype=dtype, delim_whitespace=True)
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:178: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:284: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(file_uem, names=names, dtype=dtype, delim_whitespace=True)
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:178: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:284: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(file_uem, names=names, dtype=dtype, delim_whitespace=True)
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:178: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:284: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(file_uem, names=names, dtype=dtype, delim_whitespace=True)
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:178: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:284: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(file_uem, names=names, dtype=dtype, delim_whitespace=True)
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:178: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(
# train
#    28 files
#    8h46m annotated
#    6h11m of speech (71%)
#    112 speakers
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:284: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(file_uem, names=names, dtype=dtype, delim_whitespace=True)
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:178: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:284: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(file_uem, names=names, dtype=dtype, delim_whitespace=True)
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:178: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:284: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(file_uem, names=names, dtype=dtype, delim_whitespace=True)
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:178: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(
# development
#    3 files
#    0h56m annotated
#    0h40m of speech (72%)
#    12 speakers
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:284: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(file_uem, names=names, dtype=dtype, delim_whitespace=True)
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:178: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:284: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(file_uem, names=names, dtype=dtype, delim_whitespace=True)
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:178: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:284: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(file_uem, names=names, dtype=dtype, delim_whitespace=True)
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:178: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(
# test
#    3 files
#    0h56m annotated
#    0h39m of speech (70%)
#    12 speakers

# %%
from pyannote.database import registry, FileFinder

registry.load_database("/work/proy/AMI-diarization-setup/pyannote/database.yml")
dataset = registry.get_protocol("AMI-SDM.SpeakerDiarization.mini", {"audio": FileFinder()})
# Out:
# 'AMI-SDM.SpeakerDiarization.only_words' found in /work/proy/AMI-diarization-setup/pyannote/database.yml does not define the 'scope' of speaker labels (file, database, or global). Setting it to 'file'.
# 'AMI-SDM.SpeakerDiarization.mini' found in /work/proy/AMI-diarization-setup/pyannote/database.yml does not define the 'scope' of speaker labels (file, database, or global). Setting it to 'file'.
# 'AMI.SpeakerDiarization.only_words' found in /work/proy/AMI-diarization-setup/pyannote/database.yml does not define the 'scope' of speaker labels (file, database, or global). Setting it to 'file'.
# 'AMI.SpeakerDiarization.mini' found in /work/proy/AMI-diarization-setup/pyannote/database.yml does not define the 'scope' of speaker labels (file, database, or global). Setting it to 'file'.
# 'AMI.SpeakerDiarization.word_and_vocalsounds' found in /work/proy/AMI-diarization-setup/pyannote/database.yml does not define the 'scope' of speaker labels (file, database, or global). Setting it to 'file'.

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# !pip install lightning-fabric
# Out:
# Collecting lightning-fabric
#   Obtaining dependency information for lightning-fabric from https://files.pythonhosted.org/packages/e5/99/0e7dacea67d5213c0d37c11218d137634f72fa81b348425b11ca3debc4ea/lightning_fabric-2.4.0-py3-none-any.whl.metadata
#   Downloading lightning_fabric-2.4.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: torch>=2.1.0 in /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages (from lightning-fabric) (2.4.1)
# Requirement already satisfied: fsspec[http]>=2022.5.0 in /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages (from lightning-fabric) (2024.9.0)
# Requirement already satisfied: packaging>=20.0 in /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages (from lightning-fabric) (24.1)
# Requirement already satisfied: typing-extensions>=4.4.0 in /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages (from lightning-fabric) (4.11.0)
# Requirement already satisfied: lightning-utilities>=0.10.0 in /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages (from lightning-fabric) (0.11.7)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages (from fsspec[http]>=2022.5.0->lightning-fabric) (3.10.6)
# Requirement already satisfied: setuptools in /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages (from lightning-utilities>=0.10.0->lightning-fabric) (75.1.0)
# Requirement already satisfied: filelock in /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages (from torch>=2.1.0->lightning-fabric) (3.16.1)
# Requirement already satisfied: sympy in /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages (from torch>=2.1.0->lightning-fabric) (1.13.3)
# Requirement already satisfied: networkx in /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages (from torch>=2.1.0->lightning-fabric) (3.2.1)
# Requirement already satisfied: jinja2 in /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages (from torch>=2.1.0->lightning-fabric) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages (from torch>=2.1.0->lightning-fabric) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages (from torch>=2.1.0->lightning-fabric) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages (from torch>=2.1.0->lightning-fabric) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages (from torch>=2.1.0->lightning-fabric) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages (from torch>=2.1.0->lightning-fabric) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages (from torch>=2.1.0->lightning-fabric) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages (from torch>=2.1.0->lightning-fabric) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages (from torch>=2.1.0->lightning-fabric) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages (from torch>=2.1.0->lightning-fabric) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages (from torch>=2.1.0->lightning-fabric) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages (from torch>=2.1.0->lightning-fabric) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages (from torch>=2.1.0->lightning-fabric) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=2.1.0->lightning-fabric) (12.6.68)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->lightning-fabric) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->lightning-fabric) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->lightning-fabric) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->lightning-fabric) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->lightning-fabric) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->lightning-fabric) (1.12.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->lightning-fabric) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages (from jinja2->torch>=2.1.0->lightning-fabric) (2.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages (from sympy->torch>=2.1.0->lightning-fabric) (1.3.0)
# Requirement already satisfied: idna>=2.0 in /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages (from yarl<2.0,>=1.12.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->lightning-fabric) (3.7)
# Downloading lightning_fabric-2.4.0-py3-none-any.whl (250 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 9.9 MB/s eta 0:00:00
# DEPRECATION: pytorch-lightning 1.6.5 has a non-standard dependency specifier torch>=1.8.*. pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pytorch-lightning or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: lightning-fabric
# Successfully installed lightning-fabric-2.4.0
# WARNING: There was an error checking the latest version of pip.

# %%
from pyannote.audio import Pipeline
import torch

torch.cuda.set_device(0)

pretrained_pipeline = Pipeline.from_pretrained("pyannote/speaker-diarization", use_auth_token=True)
# Out:
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pytorch_lightning/utilities/cloud_io.py:47: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# Model was trained with pyannote.audio 0.0.1, yours is 3.0.0. Bad things might happen unless you revert pyannote.audio to 0.x.
# Model was trained with torch 1.10.0+cu102, yours is 2.4.1+cu121. Bad things might happen unless you revert torch to 1.x.
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/speechbrain/utils/checkpoints.py:194: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(path, map_location=device)
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/speechbrain/processing/features.py:1311: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   stats = torch.load(path, map_location=device)

# %%
# from pyannote.audio import Pipeline
# pretrained_pipeline = Pipeline.from_pretrained("pyannote/speaker-diarization", use_auth_token=True)

# %%
from pyannote.metrics.diarization import DiarizationErrorRate
metric = DiarizationErrorRate()

for file in dataset.test():
    # apply pretrained pipeline
    file["pretrained pipeline"] = pretrained_pipeline(file)

    # evaluate its performance
    metric(file["annotation"], file["pretrained pipeline"], uem=file["annotated"])

print(f"The pretrained pipeline reaches a Diarization Error Rate (DER) of {100 * abs(metric):.1f}% on {dataset.name} test set.")
# Out:
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:178: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:284: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(file_uem, names=names, dtype=dtype, delim_whitespace=True)
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:178: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:284: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(file_uem, names=names, dtype=dtype, delim_whitespace=True)
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:178: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(
# /home/proy/miniconda3/envs/thesis_env/lib/python3.9/site-packages/pyannote/database/util.py:284: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(file_uem, names=names, dtype=dtype, delim_whitespace=True)
# The pretrained pipeline reaches a Diarization Error Rate (DER) of 32.4% on AMI-SDM.SpeakerDiarization.mini test set.
